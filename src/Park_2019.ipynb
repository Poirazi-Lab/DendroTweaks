# %%
import numpy as np
import matplotlib.pyplot as plt
from pprint import pprint

# %%
# dark theme
plt.style.use('dark_background')

# customize the style
plt.rcParams.update({
    'figure.facecolor': '#131416',
    'axes.facecolor': '#131416',
    'axes.edgecolor': 'white',
    'axes.labelcolor': 'white',
    'xtick.color': 'white',
    'ytick.color': 'white',
    'text.color': 'white',
    'axes.prop_cycle': plt.cycler(color=plt.cm.tab10.colors),  # use standard matplotlib colors
})

# %%
import dendrotweaks as dd
dd.__version__
# Out:
# '0.1.0'

# %%
import os
home = os.path.expanduser("~")
model_name = 'Park_2019'
path_to_model = os.path.join(home, 'Documents', 'code', 'DendroTweaksLab', 'DendroTweaks', 'examples', model_name)
path_to_data = os.path.dirname(path_to_model)
path_to_data
# Out:
# '/home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples'

# %%
model = dd.Model(path_to_model)

# %%
model.list_morphologies()
# Out:
# ['Park_2019']

# %%
model.load_morphology(file_name='Park_2019')
# Out:
# Removed 0 overlapping nodes.
# Removed 0 overlapping nodes.
# Soma is already in 3PS notation.
#   Elapsed time: 0.013 seconds
# Extended 44 nodes.
#   Elapsed time: 0.013 seconds
# Tree already sorted.
#   Elapsed time: 0.0 seconds
# Tree already sorted.
#   Elapsed time: 0.0 seconds

# %%
fig, ax = plt.subplots(figsize=(10, 10))
model.sec_tree.plot(ax, 
                    show_points=True,
                    show_lines=True,
                    annotate=True)

# %% [markdown]
# # Mechanisms

# %%
model.list_mechanisms()
# Out:
# ['KCa', 'sNa', 'Ka', 'Km', 'Na', 'CaLVA', 'CaHVA', 'Kv']

# %%
model.add_default_mechanisms(recompile=True)
# Out:
# /home/roman/anaconda3/envs/dendrotweaks/bin/nrnivmodl:10: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import working_set
# Translating Leak.mod into /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Default/Leak/x86_64/Leak.c
# Thread Safe
# /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Default/Leak
# Mod files: "./Leak.mod"
#
# Creating 'x86_64' directory for .o files.
#
#  -> Compiling mod_func.cpp
#  -> NMODL ../Leak.mod
#  -> Compiling Leak.c
#  => LINKING shared library ./libnrnmech.so
#  => LINKING executable ./special LDFLAGS are:    -pthread
# Successfully created x86_64/special
# /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Default/vecstim
# Mod files: "./vecstim.mod"
#
# Creating 'x86_64' directory for .o files.
#
#  -> Compiling mod_func.cpp
#  -> NMODL ../vecstim.mod
#  -> Compiling vecstim.c
#  => LINKING shared library ./libnrnmech.so
#  => LINKING executable ./special LDFLAGS are:    -pthread
# /home/roman/anaconda3/envs/dendrotweaks/bin/nrnivmodl:10: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import working_set
# Translating vecstim.mod into /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Default/vecstim/x86_64/vecstim.c
# Notice: VERBATIM blocks are not thread safe
# Successfully created x86_64/special
# /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Default/CaDyn
# Mod files: "./CaDyn.mod"
#
# Creating 'x86_64' directory for .o files.
#
#  -> Compiling mod_func.cpp
#  -> NMODL ../CaDyn.mod
#  -> Compiling CaDyn.c
#  => LINKING shared library ./libnrnmech.so
#  => LINKING executable ./special LDFLAGS are:    -pthread
# /home/roman/anaconda3/envs/dendrotweaks/bin/nrnivmodl:10: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import working_set
# Translating CaDyn.mod into /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Default/CaDyn/x86_64/CaDyn.c
# Thread Safe
# Successfully created x86_64/special
# /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Default/AMPA_NMDA
# Mod files: "./AMPA_NMDA.mod"
#
# Creating 'x86_64' directory for .o files.
#
#  -> Compiling mod_func.cpp
#  -> NMODL ../AMPA_NMDA.mod
#  -> Compiling AMPA_NMDA.c
#  => LINKING shared library ./libnrnmech.so
#  => LINKING executable ./special LDFLAGS are:    -pthread
# /home/roman/anaconda3/envs/dendrotweaks/bin/nrnivmodl:10: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import working_set
# Translating AMPA_NMDA.mod into /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Default/AMPA_NMDA/x86_64/AMPA_NMDA.c
# Thread Safe
# Successfully created x86_64/special
# /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Default/GABAa
# Mod files: "./GABAa.mod"
#
# Creating 'x86_64' directory for .o files.
#
#  -> Compiling mod_func.cpp
#  -> NMODL ../GABAa.mod
#  -> Compiling GABAa.c
#  => LINKING shared library ./libnrnmech.so
#  => LINKING executable ./special LDFLAGS are:    -pthread
# /home/roman/anaconda3/envs/dendrotweaks/bin/nrnivmodl:10: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import working_set
# Translating GABAa.mod into /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Default/GABAa/x86_64/GABAa.c
# Thread Safe
# Successfully created x86_64/special
# /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Default/NMDA
# Mod files: "./NMDA.mod"
#
# Creating 'x86_64' directory for .o files.
#
#  -> Compiling mod_func.cpp
#  -> NMODL ../NMDA.mod
#  -> Compiling NMDA.c
#  => LINKING shared library ./libnrnmech.so
#  => LINKING executable ./special LDFLAGS are:    -pthread
# /home/roman/anaconda3/envs/dendrotweaks/bin/nrnivmodl:10: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import working_set
# Translating NMDA.mod into /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Default/NMDA/x86_64/NMDA.c
# Thread Safe
# Successfully created x86_64/special
# /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Default/AMPA
# Mod files: "./AMPA.mod"
#
# Creating 'x86_64' directory for .o files.
#
#  -> Compiling mod_func.cpp
#  -> NMODL ../AMPA.mod
#  -> Compiling AMPA.c
#  => LINKING shared library ./libnrnmech.so
#  => LINKING executable ./special LDFLAGS are:    -pthread
# /home/roman/anaconda3/envs/dendrotweaks/bin/nrnivmodl:10: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import working_set
# Translating AMPA.mod into /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Default/AMPA/x86_64/AMPA.c
# Thread Safe
# Successfully created x86_64/special

# %%
model.add_mechanisms(recompile=True)
# Out:
# Saved content to /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/python/KCa.py
# /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/mod/KCa
# Mod files: "./KCa.mod"
#
# Creating 'x86_64' directory for .o files.
#
#  -> Compiling mod_func.cpp
#  -> NMODL ../KCa.mod
#  -> Compiling KCa.c
#  => LINKING shared library ./libnrnmech.so
#  => LINKING executable ./special LDFLAGS are:    -pthread
# /home/roman/anaconda3/envs/dendrotweaks/bin/nrnivmodl:10: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import working_set
# Translating KCa.mod into /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/mod/KCa/x86_64/KCa.c
# Thread Safe
# Successfully created x86_64/special
# Saved content to /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/python/sNa.py
# /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/mod/sNa
# Mod files: "./sNa.mod"
#
# Creating 'x86_64' directory for .o files.
#
#  -> Compiling mod_func.cpp
#  -> NMODL ../sNa.mod
#  -> Compiling sNa.c
#  => LINKING shared library ./libnrnmech.so
#  => LINKING executable ./special LDFLAGS are:    -pthread
# /home/roman/anaconda3/envs/dendrotweaks/bin/nrnivmodl:10: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import working_set
# Translating sNa.mod into /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/mod/sNa/x86_64/sNa.c
# Thread Safe
# Successfully created x86_64/special
# Saved content to /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/python/Ka.py
# /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/mod/Ka
# Mod files: "./Ka.mod"
#
# Creating 'x86_64' directory for .o files.
#
#  -> Compiling mod_func.cpp
#  -> NMODL ../Ka.mod
#  -> Compiling Ka.c
#  => LINKING shared library ./libnrnmech.so
#  => LINKING executable ./special LDFLAGS are:    -pthread
# /home/roman/anaconda3/envs/dendrotweaks/bin/nrnivmodl:10: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import working_set
# Translating Ka.mod into /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/mod/Ka/x86_64/Ka.c
# Thread Safe
# Successfully created x86_64/special
# Saved content to /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/python/Km.py
# /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/mod/Km
# Mod files: "./Km.mod"
#
# Creating 'x86_64' directory for .o files.
#
#  -> Compiling mod_func.cpp
#  -> NMODL ../Km.mod
#  -> Compiling Km.c
#  => LINKING shared library ./libnrnmech.so
#  => LINKING executable ./special LDFLAGS are:    -pthread
# /home/roman/anaconda3/envs/dendrotweaks/bin/nrnivmodl:10: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import working_set
# Translating Km.mod into /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/mod/Km/x86_64/Km.c
# Thread Safe
# Successfully created x86_64/special
# Saved content to /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/python/Na.py
# /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/mod/Na
# Mod files: "./Na.mod"
#
# Creating 'x86_64' directory for .o files.
#
#  -> Compiling mod_func.cpp
#  -> NMODL ../Na.mod
#  -> Compiling Na.c
#  => LINKING shared library ./libnrnmech.so
#  => LINKING executable ./special LDFLAGS are:    -pthread
# /home/roman/anaconda3/envs/dendrotweaks/bin/nrnivmodl:10: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import working_set
# Translating Na.mod into /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/mod/Na/x86_64/Na.c
# Thread Safe
# Successfully created x86_64/special
# Saved content to /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/python/CaLVA.py
# /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/mod/CaLVA
# Mod files: "./CaLVA.mod"
#
# Creating 'x86_64' directory for .o files.
#
#  -> Compiling mod_func.cpp
#  -> NMODL ../CaLVA.mod
#  -> Compiling CaLVA.c
# /home/roman/anaconda3/envs/dendrotweaks/bin/nrnivmodl:10: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import working_set
# Translating CaLVA.mod into /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/mod/CaLVA/x86_64/CaLVA.c
# Thread Safe
#  => LINKING shared library ./libnrnmech.so
#  => LINKING executable ./special LDFLAGS are:    -pthread
# Successfully created x86_64/special
# Saved content to /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/python/CaHVA.py
# /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/mod/CaHVA
# Mod files: "./CaHVA.mod"
#
# Creating 'x86_64' directory for .o files.
#
#  -> Compiling mod_func.cpp
#  -> NMODL ../CaHVA.mod
#  -> Compiling CaHVA.c
#  => LINKING shared library ./libnrnmech.so
#  => LINKING executable ./special LDFLAGS are:    -pthread
# /home/roman/anaconda3/envs/dendrotweaks/bin/nrnivmodl:10: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import working_set
# Translating CaHVA.mod into /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/mod/CaHVA/x86_64/CaHVA.c
# Thread Safe
# Successfully created x86_64/special
# Saved content to /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/python/Kv.py
# /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/mod/Kv
# Mod files: "./Kv.mod"
#
# Creating 'x86_64' directory for .o files.
#
#  -> Compiling mod_func.cpp
#  -> NMODL ../Kv.mod
#  -> Compiling Kv.c
# /home/roman/anaconda3/envs/dendrotweaks/bin/nrnivmodl:10: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import working_set
# Translating Kv.mod into /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/mod/Kv/x86_64/Kv.c
# Thread Safe
#  => LINKING shared library ./libnrnmech.so
#  => LINKING executable ./special LDFLAGS are:    -pthread
# Successfully created x86_64/special

# %%
model.mechanisms
# Out:
# {'Leak': <Mechnaism(Leak)>,
#  'CaDyn': <Mechnaism(CaDyn)>,
#  'KCa': <Mechnaism(KCa)>,
#  'sNa': <Mechnaism(sNa)>,
#  'Ka': <Mechnaism(Ka)>,
#  'Km': <Mechnaism(Km)>,
#  'Na': <Mechnaism(Na)>,
#  'CaLVA': <Mechnaism(CaLVA)>,
#  'CaHVA': <Mechnaism(CaHVA)>,
#  'Kv': <Mechnaism(Kv)>}

# %%
for domain_name in model.domains:
    if domain_name == 'axon':
        model.insert_mechanism('Leak', 'axon', distribute=False)
        continue
    for mech_name in model.mechanisms:
    # for mech_name in ['Leak', 'Na', 'Kv', 'Km', 'Ka']:
        model.insert_mechanism(mech_name, domain_name, distribute=False)

# %%
model.domains_to_mechs
# Out:
# {'axon': {'Leak'},
#  'soma': {'CaDyn',
#   'CaHVA',
#   'CaLVA',
#   'KCa',
#   'Ka',
#   'Km',
#   'Kv',
#   'Leak',
#   'Na',
#   'sNa'},
#  'apic': {'CaDyn',
#   'CaHVA',
#   'CaLVA',
#   'KCa',
#   'Ka',
#   'Km',
#   'Kv',
#   'Leak',
#   'Na',
#   'sNa'},
#  'dend': {'CaDyn',
#   'CaHVA',
#   'CaLVA',
#   'KCa',
#   'Ka',
#   'Km',
#   'Kv',
#   'Leak',
#   'Na',
#   'sNa'}}

# %%
model.df_params
# Out:
#       Mechanism    Parameter Group Distribution Distribution params
# 0   Independent           cm   all     constant        {'value': 1}
# 1   Independent           Ra   all     constant     {'value': 35.4}
# 2   Independent           ek   all     constant      {'value': -77}
# 3   Independent          ena   all     constant       {'value': 50}
# 4   Independent          eca   all     constant      {'value': 140}
# 5          Leak    gbar_Leak   all     constant      {'value': 0.0}
# 6          Leak       e_Leak   all     constant      {'value': -70}
# 7         CaDyn  depth_CaDyn   all     constant      {'value': 0.1}
# 8         CaDyn    tau_CaDyn   all     constant       {'value': 80}
# 9         CaDyn  cainf_CaDyn   all     constant   {'value': 0.0001}
# 10        CaDyn  gamma_CaDyn   all     constant     {'value': 0.05}
# 11          KCa     gbar_KCa   all     constant      {'value': 0.0}
# 12          sNa  vhalf_m_sNa   all     constant  {'value': -32.571}
# 13          sNa  sigma_m_sNa   all     constant      {'value': 9.8}
# 14          sNa      k_m_sNa   all     constant    {'value': 1.882}
# 15          sNa  delta_m_sNa   all     constant    {'value': 0.541}
# 16          sNa   tau0_m_sNa   all     constant    {'value': 0.065}
# 17          sNa  vhalf_h_sNa   all     constant    {'value': -60.0}
# 18          sNa  sigma_h_sNa   all     constant     {'value': -6.2}
# 19          sNa      k_h_sNa   all     constant    {'value': 0.018}
# 20          sNa  delta_h_sNa   all     constant    {'value': 0.395}
# 21          sNa   tau0_h_sNa   all     constant    {'value': 0.797}
# 22          sNa     gbar_sNa   all     constant      {'value': 0.0}
# 23          sNa      q10_sNa   all     constant      {'value': 2.3}
# 24          sNa     temp_sNa   all     constant       {'value': 23}
# 25           Ka      gbar_Ka   all     constant      {'value': 0.0}
# 26           Km      gbar_Km   all     constant      {'value': 0.0}
# 27           Km       v12_Km   all     constant      {'value': -30}
# 28           Km         q_Km   all     constant        {'value': 9}
# 29           Na      gbar_Na   all     constant      {'value': 0.0}
# 30           Na       Rma_Na   all     constant    {'value': 0.182}
# 31           Na       Rmb_Na   all     constant     {'value': 0.14}
# 32           Na      v12m_Na   all     constant      {'value': -30}
# 33           Na        qm_Na   all     constant      {'value': 9.8}
# 34           Na       Rhb_Na   all     constant   {'value': 0.0091}
# 35           Na       Rha_Na   all     constant    {'value': 0.024}
# 36           Na     v12ha_Na   all     constant      {'value': -45}
# 37           Na     v12hb_Na   all     constant      {'value': -70}
# 38           Na        qh_Na   all     constant        {'value': 5}
# 39           Na   v12hinf_Na   all     constant      {'value': -60}
# 40           Na     qhinf_Na   all     constant      {'value': 6.2}
# 41        CaLVA   gbar_CaLVA   all     constant      {'value': 0.0}
# 42        CaHVA   gbar_CaHVA   all     constant      {'value': 0.0}
# 43           Kv      gbar_Kv   all     constant      {'value': 0.0}
# 44           Kv       v12_Kv   all     constant       {'value': 25}
# 45           Kv         q_Kv   all     constant        {'value': 9}

# %% [markdown]
# # Groups

# %%
model.groups
# Out:
# {'all': SegmentGroup("all", domains=['axon', 'soma', 'apic', 'dend']),
#  'axonal': SegmentGroup("axonal", domains=['axon']),
#  'somatic': SegmentGroup("somatic", domains=['soma']),
#  'apical': SegmentGroup("apical", domains=['apic']),
#  'dendritic': SegmentGroup("dendritic", domains=['dend'])}

# %%
model.add_group(
    'dendritic_thin', domains=['dend', 'apic'],
    select_by='section_diam', max_value=0.8
)
model.add_group(
    'dendritic_thick', domains=['dend', 'apic'],
    select_by='section_diam', min_value=0.8
)

model.add_group(
    'proximal_apical', domains=['apic'],
    select_by='domain_distance', max_value=260
)
model.add_group(
    'distal_apical', domains=['apic'],
    select_by='domain_distance', min_value=260
)

# model.add_group('basal', domains=['dend', 'axon'])
model.add_group('basal', domains=['dend'])

# model.add_group('dendritic', domains=['dend', 'apic', 'axon'])
model.add_group('dendritic', domains=['dend', 'apic'])

# %%
model.set_param('cm', value=2)
model.set_param('cm', group_name='somatic', value=1)
model.set_param('Ra', value=100)

# %%
model.set_segmentation(d_lambda=0.1, use_neuron=True)

# %%
sec = model.sec_tree[22]
fig, ax = plt.subplots(2, 2, figsize=(12, 6))
sec.plot(ax=ax, plot_parent=True)
plt.tight_layout()

# %%
# Leak
Rm = 11000
model.set_param('gbar_Leak', value=1/Rm)

# Na
model.set_param('gbar_Na', group_name='somatic', value=0.0505)
model.set_param('gbar_Na', group_name='dendritic', value=0.0303)

# # Kv
model.set_param('gbar_Kv', group_name='somatic', value=0.005)
model.set_param('gbar_Kv', group_name='dendritic', value=0.000_15)

# # Km
model.set_param('gbar_Km', group_name='somatic', value=0.0002794)
model.set_param('gbar_Km', group_name='dendritic', value=0.000127)

# Ka
model.set_param('gbar_Ka', group_name='somatic', value=0.0054)
model.set_param('gbar_Ka', group_name='dendritic_thin', value=0.108)
model.set_param('gbar_Ka', group_name='dendritic_thick', value=0.0108)

# Kca
model.set_param('gbar_KCa', group_name='somatic', value=0.000_21)
model.set_param('gbar_KCa', group_name='dendritic', value=0.000_21)

#CaHVA
model.set_param('gbar_CaHVA', group_name='somatic', value=0.000_005)
model.set_param('gbar_CaHVA', group_name='basal', 
    distr_type='linear', slope=0.000_000_01, intercept=0.000_005)
model.set_param('gbar_CaHVA', group_name='proximal_apical', 
    distr_type='sinusoidal', amplitude=0.000_004923, frequency=0.008758, phase=0.8656)
model.set_param('gbar_CaHVA', group_name='distal_apical', value=0.000_002)

# CaLVA
model.set_param('gbar_CaLVA', group_name='somatic', value=0.000_03)
model.set_param('gbar_CaLVA', group_name='basal', 
    distr_type='linear', slope=0.000_000_06, intercept=0.000_03)
model.set_param('gbar_CaLVA', group_name='proximal_apical', 
    distr_type='sinusoidal', amplitude=0.000_029538, frequency=0.008758, phase=0.8656)
model.set_param('gbar_CaLVA', group_name='distal_apical', value=0.000_012)

# %%
model.set_param('depth_CaDyn', value=0.1)
model.set_param('tau_CaDyn', value=50)
model.set_param('cainf_CaDyn', value=1e-4)
model.set_param('gamma_CaDyn', value=1)

# %%
# for sec in model.sec_tree:
#     if sec.domain not in ['soma', 'axon']:
#         for seg in sec:
#             if sec._ref.diam > 0.8:
#                 seg._ref.gbar_Ka = 0.0108
#             else:
#                 seg._ref.gbar_Ka = 0.108

# %%
for param_name in model.conductances:
    fig, ax = plt.subplots(figsize=(10, 2))
    model.plot_param(param_name, ax=ax)

# %%
model.set_param('e_Leak', value=-79)
if 'ena' in model.params:
    model.set_param('ena', value=60)
if 'ek' in model.params:
    model.set_param('ek', value=-80)
if 'eca' in model.params:
    model.set_param('eca', value=140)
model.set_param('temperature', value=37)
model.set_param('v_init', value=-79)

# %%
# model.export_membrane(version='full')

# %%
model.distribute_all()

# %%
model.df_params
# Out:
#       Mechanism Parameter      Group Distribution Distribution params
# 0   Independent        cm        all     constant        {'value': 2}
# 1   Independent        cm    somatic     constant        {'value': 1}
# 2   Independent        Ra        all     constant      {'value': 100}
# 3   Independent        ek        all     constant      {'value': -80}
# 4   Independent       ena        all     constant       {'value': 60}
# ..          ...       ...        ...          ...                 ...
# 61           Kv   gbar_Kv        all     constant      {'value': 0.0}
# 62           Kv   gbar_Kv    somatic     constant    {'value': 0.005}
# 63           Kv   gbar_Kv  dendritic     constant  {'value': 0.00015}
# 64           Kv    v12_Kv        all     constant       {'value': 25}
# 65           Kv      q_Kv        all     constant        {'value': 9}
#
# [66 rows x 5 columns]

# %% [markdown]
# # Simulation

# %%
from dendrotweaks.analysis import detect_somatic_spikes, plot_somatic_spikes
from dendrotweaks.analysis import plot_passive_properties, calculate_passive_properties

# %%
soma = model.sec_tree.soma
soma
# Out:
# Section(idx=0)

# %% [markdown]
# ## Passive

# %%
model.remove_all_stimuli()
model.remove_all_recordings()

model.add_recording(soma, loc=0.5)
model.add_iclamp(soma, loc=0.5, amp=-0.01, delay=50, dur=900)
# Out:
# IClamp added to sec Section(idx=0) at loc 0.5.

# %%
fig, ax = plt.subplots(figsize=(10, 4))
model.simulator.run(1000);
model.simulator.plot_voltage(ax=ax)
data = calculate_passive_properties(model)
plot_passive_properties(data, ax=ax)
# Out:
# Input resistance: -119.15 MOhm
# Membrane time constant: 17.38 ms

# %%
model.export_stimuli(file_name='hyperpolarizing_current')

# %% [markdown]
# ## Somatic spikes

# %%
model.remove_all_stimuli()
model.remove_all_recordings()

model.add_recording(soma, loc=0.5)
model.add_iclamp(soma, loc=0.5, amp=0.162, delay=50, dur=900)
# Out:
# IClamp added to sec Section(idx=0) at loc 0.5.

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 4))
model.simulator.run(1000);
model.simulator.plot_voltage(ax=ax)
spike_data = detect_somatic_spikes(model)
plot_somatic_spikes(spike_data, ax, show_metrics=True)
# Out:
# Detected 7 spikes
# Average spike half-width: 0.97 ms
# Average spike amplitude: 79.03 mV
# Spike frequency: 7.78 Hz

# %%
model.export_stimuli(file_name='depolarizing_current')

# %% [markdown]
# ## Synapses

# %%
model.remove_all_stimuli()
model.remove_all_recordings()

model.add_recording(soma, loc=0.5)

segments = model.get_segments(['apical'])
model.add_population(
    segments, 
    N=50, 
    syn_type='AMPA'
)
model.update_population_input_params('AMPA_0', rate=30, end=800, noise=1)
model.update_population_kinetic_params('AMPA_0')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 7
#       4 model.add_recording(soma, loc=0.5)
#       6 segments = model.get_segments(['apical'])
# ----> 7 model.add_population(
#       8     segments,
#       9     N=50,
#      10     syn_type='AMPA'
#      11 )
#      12 model.update_population_input_params('AMPA_0', rate=30, end=800, noise=1)
#      13 model.update_population_kinetic_params('AMPA_0')
#
# File ~/Documents/code/DendroTweaksLab/DendroTweaks/src/dendrotweaks/utils.py:33, in timeit.<locals>.wrapper(*args, **kwargs)
#      31 def wrapper(*args, **kwargs):
#      32     start = time.time()
# ---> 33     result = func(*args, **kwargs)
#      34     end = time.time()
#      35     print(f"  Elapsed time: {round(end-start, 3)} seconds")
#
# File ~/Documents/code/DendroTweaksLab/DendroTweaks/src/dendrotweaks/model.py:1156, in Model.add_population(self, segments, N, syn_type)
#    1154 idx = len(self.populations[syn_type])
#    1155 population = Population(idx, segments, N, syn_type)
# -> 1156 population.allocate_synapses()
#    1157 population.create_inputs()
#    1158 self._add_population(population)
#
# File ~/Documents/code/DendroTweaksLab/DendroTweaks/src/dendrotweaks/stimuli/populations.py:187, in Population.allocate_synapses(self, syn_locs)
#     184 def allocate_synapses(self, syn_locs=None):
#     186     if syn_locs is None:
# --> 187         syn_locs = self._choose_synapse_locations()
#     188     syn_type = self.syn_type
#     189     self.synapses = {(sec, x) : [] for sec, x in syn_locs}
#
# File ~/Documents/code/DendroTweaksLab/DendroTweaks/src/dendrotweaks/stimuli/populations.py:179, in Population._choose_synapse_locations(self)
#     173 def _choose_synapse_locations(self):
#     175     valid_locs = [(sec, x) for sec in self.sections
#     176         for x in np.linspace(0, 1, 1001)
#     177         if sec(x) not in self._excluded_segments]
# --> 179     syn_locs = [np.random.choice(valid_locs) for _ in range(self.N)]
#     181     return syn_locs
#
# File ~/Documents/code/DendroTweaksLab/DendroTweaks/src/dendrotweaks/stimuli/populations.py:179, in <listcomp>(.0)
#     173 def _choose_synapse_locations(self):
#     175     valid_locs = [(sec, x) for sec in self.sections
#     176         for x in np.linspace(0, 1, 1001)
#     177         if sec(x) not in self._excluded_segments]
# --> 179     syn_locs = [np.random.choice(valid_locs) for _ in range(self.N)]
#     181     return syn_locs
#
# File numpy/random/mtrand.pyx:947, in numpy.random.mtrand.RandomState.choice()
#
# ValueError: a must be 1-dimensional

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 4))
model.run(1000)
model.simulator.plot_voltage(ax=ax)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 4))
spike_times = model.populations['AMPA']['AMPA_0'].spike_times
for i, (syn, times) in enumerate(spike_times.items()):
    ax.plot(times, np.ones_like(times) * i, '.')

ax.set_xlim(0, 1000)
ax.set_xlabel('Time (ms)')
ax.set_ylabel('Synapse ID')
ax.set_title('AMPA Synaptic Activity')
# Out:
# Text(0.5, 1.0, 'AMPA Synaptic Activity')

# %%
model.export_stimuli(file_name='50_AMPA_apical')

# %% [markdown]
# ## Nonlinearity

# %%
from dendrotweaks.analysis import calculate_dendritic_nonlinearity, plot_dendritic_nonlinearity

# %%
model.remove_all_stimuli()
model.remove_all_recordings()

sec = model.sec_tree[22]
model.add_recording(sec, loc=0.5)
segments = [sec(0.5)]

model.add_recording(sec, loc=0.5)
model.add_population(
    segments, 
    N=1, 
    syn_type='AMPA'
)

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
data = calculate_dendritic_nonlinearity(model, duration=300, max_weight=10, n=10)
plot_dendritic_nonlinearity(data, ax=ax)
# ax[0] legend positon right:
ax[0].legend(loc='right')

# %% [markdown]
# ## Attenuation

# %%
model.remove_all_stimuli()
model.remove_all_recordings()

secs = [model.sec_tree[i] for i in [0, 9, 17, 18, 21, 22]]
for sec in secs:
    model.add_recording(sec, loc=0.5)

model.add_iclamp(secs[-1], loc=0.5, amp=-0.01, delay=100, dur=800)
# Out:
# IClamp added to sec Section(idx=22) at loc 0.5.

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 4))
model.run(1000)
model.simulator.plot_voltage(ax=ax)

# %%
from dendrotweaks.analysis import calculate_voltage_attenuation, plot_voltage_attenuation

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 5))
attenuation_data = calculate_voltage_attenuation(model)
plot_voltage_attenuation(attenuation_data, ax)

# %%
model.export_stimuli(file_name='attenuation_soma')

# %% [markdown]
# ## Standardization

# %%
model.remove_all_stimuli()
model.remove_all_recordings()

model.add_recording(soma, loc=0.5)
model.add_iclamp(soma, loc=0.5, amp=0.162, delay=50, dur=900)
# Out:
# IClamp added to sec Section(idx=0) at loc 0.5.

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 4))
model.simulator.run(1000);
model.simulator.plot_voltage(ax=ax)
spike_data = detect_somatic_spikes(model)
plot_somatic_spikes(spike_data, ax, show_metrics=True)
t, v_orig = model.simulator.t, model.simulator.vs[soma(0.5)]
# Out:
# Detected 7 spikes
# Average spike half-width: 0.97 ms
# Average spike amplitude: 79.03 mV
# Spike frequency: 7.78 Hz

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
model.mechanisms['Na'].plot_kinetics(ax=ax)
model.standardize_channel('Na')
model.mechanisms['sNa'].plot_kinetics(ax=ax, linestyle='--')
# Out:
# Got data for v in range -100.0 to 100.0 at 37°C
# Got data for v in range -100.0 to 100.0 at 23°C
# UserWarning: Mechanism Na is not inserted in any domain and will be removed. (model.py, line 811)
# Saved content to /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/dendrotweaks/examples/Park_2019/membrane/mod/sNa.mod
# Got data for v in range -100.0 to 100.0 at 37°C

# %%
model.simulator.run(1000);
fig, ax = plt.subplots(1, 1, figsize=(10, 4))
# original
ax.plot(t, v_orig, color='C0', linestyle='-', zorder=0, lw=1, label='original')
# standardized
model.simulator.plot_voltage(ax=ax, linestyle='--', color='C1')
ax.legend(labels=['original', 'standardized'], loc='upper right')

# %% [markdown]
# ## f-I curve

# %%
from dendrotweaks.analysis import plot_fI_curve, calculate_fI_curve

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
fi_data = calculate_fI_curve(model, min_amp=0.14, max_amp=0.2, n=7)
plot_fI_curve(fi_data, ax) # should take about 40 seconds

# %%
from dendrotweaks.analysis import calculate_domain_statistics

# %%
calculate_domain_statistics(model, domain_names=['apic'])
# Out:
# {'apic': {'N_sections': 43,
#   'N_bifurcations': 21,
#   'N_terminations': 22,
#   'depth': {'min': 1,
#    'max': 8,
#    'counts': {1: 1, 2: 2, 3: 4, 4: 8, 5: 8, 6: 6, 7: 8, 8: 6}},
#   'diam': {'min': 0.41, 'max': 2.06, 'mean': 0.82, 'std': 0.45},
#   'length': {'min': 4.51, 'max': 154.69, 'mean': 58.31, 'std': 35.75},
#   'area': {'min': 17.6, 'max': 271.28, 'mean': 130.52, 'std': 74.2},
#   'total_length': 2507.17,
#   'total_area': 5612.19}}
