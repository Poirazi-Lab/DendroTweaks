# %%
import numpy as np
import matplotlib.pyplot as plt
from pprint import pprint

# %%
import dendrotweaks as dd
dd.__version__
# Out:
# '0.2.0'

# %%
dd.apply_dark_theme()

# %%
import os
path_to_model = os.getcwd()
path_to_data = os.path.dirname(path_to_model)

# %%
model = dd.Model(path_to_model)

# %%
model.list_morphologies()
# Out:
# ['Park_2019_sorted', 'Park_2019']

# %%
model.load_morphology(file_name='Park_2019')
# Out:
# Sorted PointTree(root=Point(idx=0), num_nodes=2214).
# Extended 44 nodes.
# Sorted PointTree(root=Point(idx=0), num_nodes=2258).

# %%
fig, ax = plt.subplots(figsize=(10, 10))
model.sec_tree.plot(ax, 
                    show_points=True,
                    show_lines=True,
                    annotate=True)

# %%
model.sec_tree.sort(sort_children=True, force=True)
# Out:
# Sorted SectionTree(root=Section(idx=0), num_nodes=52).
# Sorted PointTree(root=Point(idx=0), num_nodes=2258).
# Sorted SegmentTree(root=Segment(idx=0), num_nodes=124).

# %% [markdown]
# # Mechanisms

# %%
model.list_membrane_configs()
# Out:
# ['Park_2019_full']

# %%
model.load_membrane('Park_2019_full');
# Out:
# Saved content to /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/python/stdNa.py
# /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/mod/stdNa
# Mod files: "./stdNa.mod"
#
# Creating 'x86_64' directory for .o files.
#
#  -> Compiling mod_func.cpp
#  -> NMODL ../stdNa.mod
#  -> Compiling stdNa.c
# /home/roman/anaconda3/envs/dendrotweakstest/bin/nrnivmodl:10: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import working_set
# Translating stdNa.mod into /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/mod/stdNa/x86_64/stdNa.c
# Thread Safe
#  => LINKING shared library ./libnrnmech.so
#  => LINKING executable ./special LDFLAGS are:    -pthread
# Successfully created x86_64/special
# Saved content to /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/python/Na.py
# /home/roman/anaconda3/envs/dendrotweakstest/bin/nrnivmodl:10: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import working_set
# Translating Na.mod into /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/mod/Na/x86_64/Na.c
# Thread Safe
# /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/mod/Na
# Mod files: "./Na.mod"
#
# Creating 'x86_64' directory for .o files.
#
#  -> Compiling mod_func.cpp
#  -> NMODL ../Na.mod
#  -> Compiling Na.c
#  => LINKING shared library ./libnrnmech.so
#  => LINKING executable ./special LDFLAGS are:    -pthread
# Successfully created x86_64/special
# Saved content to /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/python/stdKv.py
# /home/roman/anaconda3/envs/dendrotweakstest/bin/nrnivmodl:10: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import working_set
# Translating stdKv.mod into /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/mod/stdKv/x86_64/stdKv.c
# Thread Safe
# /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/mod/stdKv
# Mod files: "./stdKv.mod"
#
# Creating 'x86_64' directory for .o files.
#
#  -> Compiling mod_func.cpp
#  -> NMODL ../stdKv.mod
#  -> Compiling stdKv.c
#  => LINKING shared library ./libnrnmech.so
#  => LINKING executable ./special LDFLAGS are:    -pthread
# Successfully created x86_64/special
# Saved content to /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/python/KCa.py
# /home/roman/anaconda3/envs/dendrotweakstest/bin/nrnivmodl:10: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import working_set
# Translating KCa.mod into /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/mod/KCa/x86_64/KCa.c
# Thread Safe
# /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/mod/KCa
# Mod files: "./KCa.mod"
#
# Creating 'x86_64' directory for .o files.
#
#  -> NMODL ../KCa.mod
#  -> Compiling mod_func.cpp
#  -> Compiling KCa.c
#  => LINKING shared library ./libnrnmech.so
#  => LINKING executable ./special LDFLAGS are:    -pthread
# Successfully created x86_64/special
# Saved content to /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/python/Kv.py
# /home/roman/anaconda3/envs/dendrotweakstest/bin/nrnivmodl:10: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import working_set
# Translating Kv.mod into /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/mod/Kv/x86_64/Kv.c
# Thread Safe
# /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/mod/Kv
# Mod files: "./Kv.mod"
#
# Creating 'x86_64' directory for .o files.
#
#  -> Compiling mod_func.cpp
#  -> NMODL ../Kv.mod
#  -> Compiling Kv.c
#  => LINKING shared library ./libnrnmech.so
#  => LINKING executable ./special LDFLAGS are:    -pthread
# Successfully created x86_64/special
# Saved content to /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/python/Ka.py
# /home/roman/anaconda3/envs/dendrotweakstest/bin/nrnivmodl:10: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import working_set
# Translating Ka.mod into /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/mod/Ka/x86_64/Ka.c
# Thread Safe
# /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/mod/Ka
# Mod files: "./Ka.mod"
#
# Creating 'x86_64' directory for .o files.
#
#  -> Compiling mod_func.cpp
#  -> NMODL ../Ka.mod
#  -> Compiling Ka.c
#  => LINKING shared library ./libnrnmech.so
#  => LINKING executable ./special LDFLAGS are:    -pthread
# Successfully created x86_64/special
# Saved content to /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/python/CaHVA.py
# /home/roman/anaconda3/envs/dendrotweakstest/bin/nrnivmodl:10: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import working_set
# Translating CaHVA.mod into /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/mod/CaHVA/x86_64/CaHVA.c
# Thread Safe
# /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/mod/CaHVA
# Mod files: "./CaHVA.mod"
#
# Creating 'x86_64' directory for .o files.
#
#  -> Compiling mod_func.cpp
#  -> NMODL ../CaHVA.mod
#  -> Compiling CaHVA.c
#  => LINKING shared library ./libnrnmech.so
#  => LINKING executable ./special LDFLAGS are:    -pthread
# Successfully created x86_64/special
# Saved content to /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/python/Km.py
# /home/roman/anaconda3/envs/dendrotweakstest/bin/nrnivmodl:10: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import working_set
# Translating Km.mod into /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/mod/Km/x86_64/Km.c
# Thread Safe
# /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/mod/Km
# Mod files: "./Km.mod"
#
# Creating 'x86_64' directory for .o files.
#
#  -> Compiling mod_func.cpp
#  -> NMODL ../Km.mod
#  -> Compiling Km.c
#  => LINKING shared library ./libnrnmech.so
#  => LINKING executable ./special LDFLAGS are:    -pthread
# Successfully created x86_64/special
# Saved content to /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/python/CaLVA.py
# /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/mod/CaLVA
# Mod files: "./CaLVA.mod"
#
# Creating 'x86_64' directory for .o files.
#
#  -> Compiling mod_func.cpp
#  -> NMODL ../CaLVA.mod
#  -> Compiling CaLVA.c
# /home/roman/anaconda3/envs/dendrotweakstest/bin/nrnivmodl:10: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import working_set
# Translating CaLVA.mod into /home/roman/Documents/code/DendroTweaksLab/DendroTweaks/examples/Park_2019/membrane/mod/CaLVA/x86_64/CaLVA.c
# Thread Safe
#  => LINKING shared library ./libnrnmech.so
#  => LINKING executable ./special LDFLAGS are:    -pthread
# Successfully created x86_64/special

# %%
model.domains_to_mechs
# Out:
# {'apic': {'CaDyn', 'CaHVA', 'CaLVA', 'KCa', 'Ka', 'Km', 'Kv', 'Leak', 'Na'},
#  'axon': {'Leak'},
#  'dend': {'CaDyn', 'CaHVA', 'CaLVA', 'KCa', 'Ka', 'Km', 'Kv', 'Leak', 'Na'},
#  'soma': {'CaDyn', 'CaHVA', 'CaLVA', 'KCa', 'Ka', 'Km', 'Kv', 'Leak', 'Na'}}

# %%
model.df_params
# Out:
#       Mechanism    Parameter            Group Distribution  \
# 0   Independent           cm              all     constant
# 1   Independent           cm          somatic     constant
# 2   Independent           Ra              all     constant
# 3   Independent          eca              all     constant
# 4   Independent           ek              all     constant
# 5   Independent          ena              all     constant
# 6          Leak    gbar_Leak              all     constant
# 7          Leak       e_Leak              all     constant
# 8         CaDyn  depth_CaDyn              all     constant
# 9         CaDyn    tau_CaDyn              all     constant
# 10        CaDyn  cainf_CaDyn              all     constant
# 11        CaDyn  gamma_CaDyn              all     constant
# 12        CaHVA   gbar_CaHVA              all     constant
# 13        CaHVA   gbar_CaHVA          somatic     constant
# 14        CaHVA   gbar_CaHVA            basal       linear
# 15        CaHVA   gbar_CaHVA  proximal_apical   sinusoidal
# 16        CaHVA   gbar_CaHVA    distal_apical     constant
# 17        CaLVA   gbar_CaLVA              all     constant
# 18        CaLVA   gbar_CaLVA          somatic     constant
# 19        CaLVA   gbar_CaLVA            basal       linear
# 20        CaLVA   gbar_CaLVA  proximal_apical   sinusoidal
# 21        CaLVA   gbar_CaLVA    distal_apical     constant
# 22          KCa     gbar_KCa              all     constant
# 23          KCa     gbar_KCa          somatic     constant
# 24          KCa     gbar_KCa        dendritic     constant
# 25           Ka      gbar_Ka              all     constant
# 26           Ka      gbar_Ka          somatic     constant
# 27           Ka      gbar_Ka   dendritic_thin     constant
# 28           Ka      gbar_Ka  dendritic_thick     constant
# 29           Km      gbar_Km              all     constant
# 30           Km      gbar_Km          somatic     constant
# 31           Km      gbar_Km        dendritic     constant
# 32           Km       v12_Km              all     constant
# 33           Km         q_Km              all     constant
# 34           Kv      gbar_Kv              all     constant
# 35           Kv      gbar_Kv          somatic     constant
# 36           Kv      gbar_Kv        dendritic     constant
# 37           Kv       v12_Kv              all     constant
# 38           Kv         q_Kv              all     constant
# 39           Na      gbar_Na              all     constant
# 40           Na      gbar_Na          somatic     constant
# 41           Na      gbar_Na        dendritic     constant
# 42           Na       Rma_Na              all     constant
# 43           Na       Rmb_Na              all     constant
# 44           Na      v12m_Na              all     constant
# 45           Na        qm_Na              all     constant
# 46           Na       Rhb_Na              all     constant
# 47           Na       Rha_Na              all     constant
# 48           Na     v12ha_Na              all     constant
# 49           Na     v12hb_Na              all     constant
# 50           Na        qh_Na              all     constant
# 51           Na   v12hinf_Na              all     constant
# 52           Na     qhinf_Na              all     constant
#
#                                   Distribution params
# 0                                        {'value': 2}
# 1                                        {'value': 1}
# 2                                      {'value': 100}
# 3                                      {'value': 140}
# 4                                      {'value': -80}
# 5                                       {'value': 60}
# 6                     {'value': 9.09090909090909e-05}
# 7                                      {'value': -79}
# 8                                      {'value': 0.1}
# 9                                       {'value': 50}
# 10                                  {'value': 0.0001}
# 11                                       {'value': 1}
# 12                                     {'value': 0.0}
# 13                                   {'value': 5e-06}
# 14               {'slope': 1e-08, 'intercept': 5e-06}
# 15  {'amplitude': 4.923e-06, 'frequency': 0.008758...
# 16                                   {'value': 2e-06}
# 17                                     {'value': 0.0}
# 18                                   {'value': 3e-05}
# 19               {'slope': 6e-08, 'intercept': 3e-05}
# 20  {'amplitude': 2.9538e-05, 'frequency': 0.00875...
# 21                                 {'value': 1.2e-05}
# 22                                     {'value': 0.0}
# 23                                 {'value': 0.00021}
# 24                                 {'value': 0.00021}
# 25                                     {'value': 0.0}
# 26                                  {'value': 0.0054}
# 27                                   {'value': 0.108}
# 28                                  {'value': 0.0108}
# 29                                     {'value': 0.0}
# 30                               {'value': 0.0002794}
# 31                                {'value': 0.000127}
# 32                                     {'value': -30}
# 33                                       {'value': 9}
# 34                                     {'value': 0.0}
# 35                                   {'value': 0.005}
# 36                                 {'value': 0.00015}
# 37                                      {'value': 25}
# 38                                       {'value': 9}
# 39                                     {'value': 0.0}
# 40                                  {'value': 0.0505}
# 41                                  {'value': 0.0303}
# 42                                   {'value': 0.182}
# 43                                    {'value': 0.14}
# 44                                     {'value': -30}
# 45                                     {'value': 9.8}
# 46                                  {'value': 0.0091}
# 47                                   {'value': 0.024}
# 48                                     {'value': -45}
# 49                                     {'value': -70}
# 50                                       {'value': 5}
# 51                                     {'value': -60}
# 52                                     {'value': 6.2}

# %%
len(model.seg_tree)
# Out:
# 246

# %% [markdown]
# # Groups

# %%
model.groups
# Out:
# {'all': SegmentGroup("all", domains=['apic', 'axon', 'dend', 'soma']),
#  'apical': SegmentGroup("apical", domains=['apic']),
#  'axonal': SegmentGroup("axonal", domains=['axon']),
#  'dendritic': SegmentGroup("dendritic", domains=['dend', 'apic']),
#  'somatic': SegmentGroup("somatic", domains=['soma']),
#  'dendritic_thin': SegmentGroup("dendritic_thin", domains=['dend', 'apic'], section_diam(None, 0.8)),
#  'dendritic_thick': SegmentGroup("dendritic_thick", domains=['dend', 'apic'], section_diam(0.8, None)),
#  'proximal_apical': SegmentGroup("proximal_apical", domains=['apic'], distance(None, 260)),
#  'distal_apical': SegmentGroup("distal_apical", domains=['apic'], distance(260, None)),
#  'basal': SegmentGroup("basal", domains=['dend'])}

# %%
for param_name in model.conductances:
    fig, ax = plt.subplots(figsize=(10, 2))
    model.plot_param(param_name, ax=ax)

# %%
model.list_stimuli_configs()
# Out:
# ['hyperpolarizing_current',
#  'depolarizing_current',
#  '50_AMPA_apical',
#  'attenuation_soma']

# %%
model.load_stimuli('depolarizing_current')
# Out:
# Recording added to sec Section(idx=0) at loc 0.5.
# IClamp added to sec Section(idx=0) at loc 0.5.

# %%
soma = model.sec_tree[0]

# %%
model.iclamps[soma(0.5)].amp
# Out:
# 0.162

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 4))
model.run(1000)
model.simulator.plot_voltage(ax=ax)
plt.title('Somatic spikes')
# Out:
# Text(0.5, 1.0, 'Somatic spikes')

# %%
# all_seg = model.seg_tree[:]
v = np.array(list(model.simulator.vs.values())[0])
diam = np.array([seg._ref.diam for seg in model.seg_tree])
calva = np.array([getattr(seg._ref, 'gbar_CaLVA', 0) for seg in model.seg_tree])

# %%
plt.plot(calva, '.')

# %%
# save the array of the voltage
path_to_voltage = os.path.join(path_to_model, 'voltage.npy')
path_to_diams = os.path.join(path_to_model, 'diams.npy')
path_to_calva = os.path.join(path_to_model, 'calva.npy')
np.save(path_to_voltage, v)
np.save(path_to_diams, diam)
np.save(path_to_calva, calva)

# %%
model.export_to_NEURON(file_name='Park_2019_NEURON', include_kinetic_params=True)
